# %%
import pandas as pd
import numpy as np
import os

os.chdir('/Users/antoniojurlina/Google Drive/Spring 2021/SIE 598/data/')

# %%
real=pd.read_csv('RDC_Inventory_Core_Metrics_State_History.csv')

# %%
real.tail()
# Out:
#       month_date_yyyymm           state state_id  median_listing_price  \
# 2800             201607            iowa       ia              169950.0
# 2801             201607  south carolina       sc              239950.0
# 2802             201607        nebraska       ne              193050.0
# 2803             201607        virginia       va              285050.0
# 2804             201607   west virginia       wv              165050.0
#
#       median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 2800                      NaN                      NaN                 14764
# 2801                      NaN                      NaN                 35380
# 2802                      NaN                      NaN                  5132
# 2803                      NaN                      NaN                 49354
# 2804                      NaN                      NaN                 10021
#
# ...

# %%
real.shape
# Out:
# (2805, 39)

# %%
real.shape[0]/51
# Out:
# 55.0

# %%
real.set_index('month_date_yyyymm', inplace=True)
real.head()
# Out:
#                           state state_id  median_listing_price  \
# month_date_yyyymm
# 202101                 delaware       de              358050.0
# 202101                    idaho       id              465040.0
# 202101                  arizona       az              419050.0
# 202101             north dakota       nd              235050.0
# 202101                 maryland       md              349050.0
#
#                    median_listing_price_mm  median_listing_price_yy  \
# month_date_yyyymm
# 202101                              0.0258                   0.1002
# 202101                              0.0816                   0.2433
# 202101                              0.0771                   0.1403
# 202101                             -0.0053                   0.0444
# 202101                              0.0205                   0.0579
#
#                    active_listing_count  active_listing_count_mm  \
# month_date_yyyymm
# ...

# %%
a1=real[(real.index == 202101) | (real.index == 202001)]

# %%
a1.shape
# Out:
# (102, 38)

# %%
a1.head()
# Out:
#                           state state_id  median_listing_price  \
# month_date_yyyymm
# 202101                 delaware       de              358050.0
# 202101                    idaho       id              465040.0
# 202101                  arizona       az              419050.0
# 202101             north dakota       nd              235050.0
# 202101                 maryland       md              349050.0
#
#                    median_listing_price_mm  median_listing_price_yy  \
# month_date_yyyymm
# 202101                              0.0258                   0.1002
# 202101                              0.0816                   0.2433
# 202101                              0.0771                   0.1403
# 202101                             -0.0053                   0.0444
# 202101                              0.0205                   0.0579
#
#                    active_listing_count  active_listing_count_mm  \
# month_date_yyyymm
# ...

# %%
state_set=set(a1.state)

# %%
len(state_set)

# %%
a21=a1.loc[[202101],['state','median_listing_price','active_listing_count','median_days_on_market']]
a21.head(10)

# %%
a21.set_index("state", inplace=True)
a21.head(10)

# %%
a3=a21.rename(columns={'median_listing_price': 'MLP', 'active_listing_count': "ALC",'median_days_on_market': 'MDOM'})

# %%
a3.head(8)

# %%
a20=a1.loc[[202001],['state','median_listing_price','active_listing_count','median_days_on_market']]
a20.head(10)

# %%
a20.set_index("state", inplace=True)
a20.head(10)

# %%
a4=a20.rename(columns={'median_listing_price': 'MLP', 'active_listing_count': "ALC",'median_days_on_market': 'MDOM'})

# %%
a4.head(8)

# %%
subtractionResults = a3 - a4 # Jan 2021 - Jan 2020

# %%
subtractionResults

# %%
a3.loc['delaware']

# %%
a4.loc['delaware']

# %%
a3.loc['delaware']-a4.loc['delaware']

# %%
real.columns
